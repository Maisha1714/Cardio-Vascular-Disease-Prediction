# %% [markdown]
# <a href="https://colab.research.google.com/github/Maisha1714/Cardio-Vascular-Disease-Prediction/blob/main/Cardiovascular_Disease_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/cardio_train.csv',sep =';')
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
df.shape
# Out:
# (70000, 13)

# %%
df['cardio'].value_counts()
# Out:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64

# %% [markdown]
# # **Cardio Status in percentage**

# %%
round(df['cardio'].value_counts()*100/len(df))  #balanced data
# Out:
# cardio
# 0    50.0
# 1    50.0
# Name: count, dtype: float64

# %%
sns.countplot(x=df['cardio'])
# Out:
# <Axes: xlabel='cardio', ylabel='count'>

# %%
sns.countplot(x='gender', data=df, hue='cardio', palette='colorblind', edgecolor=sns.color_palette('dark')[0])
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
df['yr'] = (df['age']/365).round(0) # Recalculate the 'yr' column and ensure it's added to the DataFrame
sns.countplot(x ='yr',data = df,hue = 'cardio',palette = 'colorblind',edgecolor = sns.color_palette ('dark')[0])
# Out:
# <Axes: xlabel='yr', ylabel='count'>

# %%
df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   19468.865814      1.349571    164.359229     74.205690    128.817286
# std     2467.251667      0.476838      8.210126     14.395757    154.011419
# min    10798.000000      1.000000     55.000000     10.000000   -150.000000
# 25%    17664.000000      1.000000    159.000000     65.000000    120.000000
# 50%    19703.000000      1.000000    165.000000     72.000000    120.000000
# 75%    21327.000000      2.000000    170.000000     82.000000    140.000000
# max    23713.000000      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      96.630414      1.366871      1.226457      0.088129      0.053771
# ...

# %%
df.corr()
# Out:
#                   age    gender    height    weight     ap_hi     ap_lo  \
# age          1.000000 -0.022811 -0.081515  0.053684  0.020764  0.017647
# gender      -0.022811  1.000000  0.499033  0.155406  0.006005  0.015254
# height      -0.081515  0.499033  1.000000  0.290968  0.005488  0.006150
# weight       0.053684  0.155406  0.290968  1.000000  0.030702  0.043710
# ap_hi        0.020764  0.006005  0.005488  0.030702  1.000000  0.016086
# ap_lo        0.017647  0.015254  0.006150  0.043710  0.016086  1.000000
# cholesterol  0.154424 -0.035821 -0.050226  0.141768  0.023778  0.024019
# gluc         0.098703 -0.020491 -0.018595  0.106857  0.011841  0.010806
# smoke       -0.047633  0.338135  0.187989  0.067780 -0.000922  0.005186
# alco        -0.029723  0.170966  0.094419  0.067113  0.001408  0.010601
# active      -0.009927  0.005866 -0.006570 -0.016867 -0.000033  0.004780
# cardio       0.238159  0.008109 -0.010821  0.181660  0.054475  0.065719
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol',
#        'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
##df.drop(['yr'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol',
#        'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
x = df.iloc[:,:-1]

# %%
x
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active
# 0         0       1
# ...

# %%
y = df.iloc[:,11]
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 0.3,random_state = 1)

# %%
xtrain
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 23561  16136       2     169    71.0    100     80            1     1      1
# 34858  14615       1     158    69.0    140     80            2     1      0
# 54953  20507       1     164    65.0    120     80            1     1      0
# 59230  16720       1     153    53.0    100     60            1     1      0
# 1730   21050       1     159    71.0    140     90            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 49100  21289       2     175    78.0    120     80            1     1      0
# 20609  19116       1     164    68.0    120     80            1     1      0
# 21440  18049       2     178    82.0    120     80            1     1      0
# 50057  21957       1     169    77.0    120     80            1     1      0
# 5192   20671       1     174    65.0    160     90            2     2      0
#
#        alco  active
# 23561     0       1
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
RFCL = RandomForestClassifier()

# %%
RFCL.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
RFCL.score(xtest,ytest)
# Out:
# 0.7186666666666667

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
CLF = DecisionTreeClassifier()

# %%
CLF.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
CLF.score(xtest,ytest)
# Out:
# 0.6357142857142857
